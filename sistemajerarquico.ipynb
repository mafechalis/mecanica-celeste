# %%
# !pip install -Uq pymcel

# %%
# !pip install -Uq numpy

# %%
import numpy as np

# %%
import pymcel as pc
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-a041f10890eb> in <module>
# ----> 1 import pymcel as pc
#
# ~/anaconda3/lib/python3.8/site-packages/pymcel/__init__.py in <module>
#       8 import types
#       9 import matplotlib.pyplot as plt
# ---> 10 from scipy.integrate import quad
#      11 from numpy import sin, cos
#      12 from spiceypy import mxv
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/__init__.py in <module>
#      88    solve_bvp     -- Solve a boundary value problem for a system of ODEs.
#      89 """
# ---> 90 from ._quadrature import *
#      91 from .odepack import *
#      92 from .quadpack import *
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/_quadrature.py in <module>
#       8 # even though it's actually a NumPy function.
#       9 from numpy import trapz
# ---> 10 from scipy.special import roots_legendre
# ...

# %%
G=1

# %%
m_Zul_Aa=1
m_Zul_Ab=0.01

RCM_Zul_Aa=np.array([0,0,0])
VCM_Zul_Aa=np.array([0,0,0])

r_Zul_Aa=np.array([0.1,0,0])
v_Zul_Aa=np.array([0.1,0,0])

# %%
m_Zul_Aab= m_Zul_Aa+m_Zul_Ab
m_Zul_B=1.0

r_Zul_AB=np.array([1.0,0.0,0.0])
v_Zul_AB=np.array([0.0,1.0,0.0])

# %%
RCM_Zul_AB=np.array([0,0,0])
VCM_Zul_AB=np.array([0,0,0])

# %%
r_Zul_B=RCM_Zul_AB-m_Zul_Aab/(m_Zul_B+m_Zul_Aab)*r_Zul_AB
v_Zul_B=VCM_Zul_AB-m_Zul_Aab/(m_Zul_B+m_Zul_Aab)*v_Zul_AB

# %%
RCM_Zul_A=RCM_Zul_AB+m_Zul_B/(m_Zul_B+m_Zul_Aab)*r_Zul_AB
VCM_Zul_A=VCM_Zul_AB+m_Zul_B/(m_Zul_B+m_Zul_Aab)*v_Zul_AB

# %%
#particula 1
r_Zul_Aa=RCM_Zul_A+m_Zul_Ab/(m_Zul_Aab)*r_Zul_Aa
v_Zul_Aa=VCM_Zul_A+m_Zul_Ab/(m_Zul_Aab)*v_Zul_Aa

#particula 2
r_Zul_Ab=RCM_Zul_A-m_Zul_Aa/(m_Zul_Aab)*r_Zul_B
v_Zul_Ab=VCM_Zul_A-m_Zul_Aa/(m_Zul_Aab)*v_Zul_B
